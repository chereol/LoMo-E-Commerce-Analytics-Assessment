# %% [markdown]
# # Libraries

# %%
# Standard libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.gridspec import GridSpec
pd.set_option('display.max_columns', 100)
import plotly.offline as py
import plotly.express as px
import plotly.graph_objs as go
import json
import requests
import folium
from folium.plugins import FastMarkerCluster, Fullscreen, MiniMap, HeatMap, HeatMapWithTime, LocateControl

# %% [markdown]
# # Load Files

# %%
#loading all csv files
customer     = pd.read_csv("C:/Users/ccher/OneDrive/Desktop/PwC Assn/001_lomo_customers_dataset.csv")
geo_location = pd.read_csv("C:/Users/ccher/OneDrive/Desktop/PwC Assn/003_lomo_geolocation_dataset.csv")
items        = pd.read_csv("C:/Users/ccher/OneDrive/Desktop/PwC Assn/007_lomo_order_items_dataset.csv")
payments     = pd.read_csv("C:/Users/ccher/OneDrive/Desktop/PwC Assn/008_lomo_order_payments_dataset.csv")
reviews      = pd.read_csv("C:/Users/ccher/OneDrive/Desktop/PwC Assn/009_lomo_order_reviews_dataset.csv")
orders       = pd.read_csv("C:/Users/ccher/OneDrive/Desktop/PwC Assn/006_lomo_orders_dataset.csv")
products     = pd.read_csv("C:/Users/ccher/OneDrive/Desktop/PwC Assn/004_lomo_products_dataset.csv")
sellers      = pd.read_csv("C:/Users/ccher/OneDrive/Desktop/PwC Assn/002_lomo_sellers_dataset.csv")
translation  = pd.read_csv("C:/Users/ccher/OneDrive/Desktop/PwC Assn/005_lomo_product_category_name_translation.csv")
closed_deals = pd.read_csv("C:/Users/ccher/OneDrive/Desktop/PwC Assn/011_lomo_closed_deals_dataset.csv")

# %% [markdown]
# # Overview of data sets

# %%
def overview(dataframe):
    """This function will return the overview of the dataframe"""
    
    print("Shape of the dataframe is : {}".format(dataframe.shape))
    print("**"*30)
    print("Information about features : ",dataframe.info())
    print("**"*30)
    print("Total number of null values : \n ",dataframe.isnull().sum())
    print("**"*30)
    
    return dataframe.head(3)

# %%
overview(customer)
# Out:
# Shape of the dataframe is : (99441, 5)
# ************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  object
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: object(5)
# memory usage: 3.8+ MB
# Information about features :  None
# ************************************************************
# Total number of null values :
#   customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
# ************************************************************
#                         customer_id                customer_unique_id  \
# 0  8535e7d171732dcdb3de48ff99040f6c  05c0c68fbdf283e56b37df9f2d20245c
# 1  045ce65dc053765839733057c287dbcb  1f69219bc86e6918b4751692323de642
# 2  c754052065714c0e304de22a0e5b7749  31b5e7b0290cf70ac603e77f85efb53f
#
#   customer_zip_code_prefix customer_city customer_state
# 0                 TH100101   Phra Nakhon        Bangkok
# 1                 TH100101   Phra Nakhon        Bangkok
# 2                 TH100101   Phra Nakhon        Bangkok

# %%
overview(geo_location)
# Out:
# Shape of the dataframe is : (7425, 16)
# ************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7425 entries, 0 to 7424
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   object_id       7425 non-null   int64
#  1   shape           7425 non-null   object
#  2   admin0_name_en  7425 non-null   object
#  3   admin0_name_th  7425 non-null   object
#  4   admin0_pcode    7425 non-null   object
#  5   admin1_name_en  7425 non-null   object
#  6   admin1_name_th  7425 non-null   object
#  7   admin1_pcode    7425 non-null   object
#  8   admin2_name_en  7425 non-null   object
#  9   admin2_name_th  7425 non-null   object
#  10  admin2_pcode    7425 non-null   object
#  11  admin3_name_en  7425 non-null   object
#  12  admin3_name_th  7425 non-null   object
#  13  admin3_pcode    7425 non-null   object
#  14  shape_length    7425 non-null   float64
#  15  shape_area      7425 non-null   float64
# dtypes: float64(2), int64(1), object(13)
# memory usage: 928.2+ KB
# Information about features :  None
# ************************************************************
# Total number of null values :
#   object_id         0
# shape             0
# admin0_name_en    0
# admin0_name_th    0
# admin0_pcode      0
# admin1_name_en    0
# admin1_name_th    0
# admin1_pcode      0
# admin2_name_en    0
# admin2_name_th    0
# admin2_pcode      0
# admin3_name_en    0
# admin3_name_th    0
# admin3_pcode      0
# shape_length      0
# shape_area        0
# dtype: int64
# ************************************************************
#    object_id    shape admin0_name_en admin0_name_th admin0_pcode  \
# 0          1  Polygon       Thailand      ประเทศไทย           TH
# 1          2  Polygon       Thailand      ประเทศไทย           TH
# 2          3  Polygon       Thailand      ประเทศไทย           TH
#
#   admin1_name_en admin1_name_th admin1_pcode  admin2_name_en admin2_name_th  \
# 0           Loei            เลย         TH42          Tha Li         ท่าลี่
# 1        Pattani        ปัตตานี         TH94  Mueang Pattani   เมืองปัตตานี
# 2          Surin       สุรินทร์         TH32         Buachet         บัวเชด
#
#   admin2_pcode admin3_name_en admin3_name_th admin3_pcode  shape_length  \
# 0       TH4208           A Hi           อาฮี     TH420803      0.360041
# 1       TH9401         A Noru       อาเนาะรู     TH940102      0.044900
# 2       TH3213         A Phon          อาโพน     TH321305      0.365838
#
#    shape_area
# 0    0.005078
# 1    0.000120
# 2    0.004086

# %%
overview(reviews)
# Out:
# Shape of the dataframe is : (100000, 7)
# ************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   review_id                100000 non-null  object
#  1   order_id                 100000 non-null  object
#  2   review_score             100000 non-null  int64
#  3   review_comment_title     11715 non-null   object
#  4   review_comment_message   41753 non-null   object
#  5   review_creation_date     100000 non-null  object
#  6   review_answer_timestamp  100000 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB
# Information about features :  None
# ************************************************************
# Total number of null values :
#   review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       88285
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64
# ************************************************************
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
#
#    review_score review_comment_title review_comment_message  \
# 0             4                  NaN                    NaN
# 1             5                  NaN                    NaN
# 2             5                  NaN                    NaN
#
#   review_creation_date review_answer_timestamp
# 0     18/01/2018 00:00        18/01/2018 21:46
# 1     10/03/2018 00:00        11/03/2018 03:05
# 2     17/02/2018 00:00        18/02/2018 14:36

# %%
overview(products)
# Out:
# Shape of the dataframe is : (32340, 9)
# ************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32340 entries, 0 to 32339
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32340 non-null  object
#  1   product_category_name       32340 non-null  object
#  2   product_name_lenght         32340 non-null  int64
#  3   product_description_lenght  32340 non-null  int64
#  4   product_photos_qty          32340 non-null  int64
#  5   product_weight_g            32340 non-null  int64
#  6   product_length_cm           32340 non-null  int64
#  7   product_height_cm           32340 non-null  int64
#  8   product_width_cm            32340 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 2.2+ MB
# Information about features :  None
# ************************************************************
# Total number of null values :
#   product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64
# ************************************************************
#                          product_id product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5            perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                 artes
# 2  96bd76ec8810374ed1b65e291975717f         esporte_lazer
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                   40                         287                   1
# 1                   44                         276                   1
# 2                   46                         250                   1
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0               225                 16                 10                14
# 1              1000                 30                 18                20
# 2               154                 18                  9                15

# %%
overview(orders)
# Out:
# Shape of the dataframe is : (99441, 8)
# ************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
# Information about features :  None
# ************************************************************
# Total number of null values :
#   order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64
# ************************************************************
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered         02/10/2017 10:56  02/10/2017 11:07
# 1    delivered         24/07/2018 20:41  26/07/2018 03:24
# 2    delivered         08/08/2018 08:38  08/08/2018 08:55
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0             04/10/2017 19:55              10/10/2017 21:25
# 1             26/07/2018 14:31              07/08/2018 15:27
# 2             08/08/2018 13:50              17/08/2018 18:06
#
#   order_estimated_delivery_date
# 0              18/10/2017 00:00
# 1              13/08/2018 00:00
# 2              04/09/2018 00:00

# %% [markdown]
# # Observations from overview:

# %% [markdown]
# - There are null values in orders data and reviews data. Rest of the dataframes do not have any null values
# - Translation data has the product category names in english so we can use this to get product category
# - To get the complete informations, we need to merge these sub dataframes to get single dataframe. Merging should be done according to the data schema that is given.

# %% [markdown]
# # Rename and Merging

# %%
#zip_code_prefix column has different names in customer,geo_location,sellers dataframes
#Change these names to zip_code_prefix

customer.rename(columns = {"customer_zip_code_prefix":"zip_code_prefix"},inplace=True)
geo_location.rename(columns = {"admin3_pcode":"zip_code_prefix"},inplace=True)
sellers.rename(columns = {"seller_zip_code_prefix":"zip_code_prefix"},inplace=True)

# %%
#customer merging with geo_location (left join to preserve customer info)
geo_customer     = pd.merge(customer,geo_location,how="left",on="zip_code_prefix")

#sellers merging with geo_locations (left join to preserve sellers info)
geo_seller       = pd.merge(sellers,geo_location,how="left",on="zip_code_prefix")

#payment merging with order
payment_order    = pd.merge(payments,orders,on="order_id")

#product merging with item
product_item     = pd.merge(products,items,on="product_id")

#payment_order merging with reviews
pay_order_review = pd.merge(payment_order,reviews,on="order_id")

#pay_order_review merging with geo_customer
review_customer  = pd.merge(pay_order_review,geo_customer,on="customer_id")

#prod_item merging with geo_seller
prod_item_seller = pd.merge(product_item,geo_seller,on="seller_id")

#Finally review_customer with prod_item_seller
data             = pd.merge(review_customer,prod_item_seller,on="order_id",suffixes=("_customer","_seller"))

# %%
print("Shape of the final dataframe (data) is : ",data.shape)
# Out:
# Shape of the final dataframe (data) is :  (116605, 72)

# %%
num_tot_rows = data.shape[0]

# %%
print("All the column names in the data : \n",data.columns)
# Out:
# All the column names in the data :
#  Index(['order_id', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value', 'customer_id', 'order_status',
#        'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp', 'customer_unique_id',
#        'zip_code_prefix_customer', 'customer_city', 'customer_state',
#        'object_id_customer', 'shape_customer', 'admin0_name_en_customer',
#        'admin0_name_th_customer', 'admin0_pcode_customer',
#        'admin1_name_en_customer', 'admin1_name_th_customer',
#        'admin1_pcode_customer', 'admin2_name_en_customer',
#        'admin2_name_th_customer', 'admin2_pcode_customer',
#        'admin3_name_en_customer', 'admin3_name_th_customer',
#        'shape_length_customer', 'shape_area_customer', 'product_id',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'order_item_id', 'seller_id', 'shipping_limit_date', 'price',
#        'freight_value', 'seller_zip_code_prefix_prep', 'seller_city_prep',
#        'seller_state_prep', 'zip_code_prefix_seller', 'seller_city',
#        'seller_state', 'object_id_seller', 'shape_seller',
#        'admin0_name_en_seller', 'admin0_name_th_seller', 'admin0_pcode_seller',
#        'admin1_name_en_seller', 'admin1_name_th_seller', 'admin1_pcode_seller',
#        'admin2_name_en_seller', 'admin2_name_th_seller', 'admin2_pcode_seller',
#        'admin3_name_en_seller', 'admin3_name_th_seller', 'shape_length_seller',
#        'shape_area_seller'],
#       dtype='object')

# %% [markdown]
# We don't need to use the review text, comment,review creation date. Hence it is better to drop these columns now.

# %%
data.drop(['review_id','review_comment_title', 'review_comment_message',
          'review_creation_date','review_answer_timestamp'],axis=1,inplace=True)

# %%
#Checking for null values
obj = data.isnull().sum()
for key,value in obj.iteritems():
    print(key,",",value)
# Out:
# order_id , 0
# payment_sequential , 0
# payment_type , 0
# payment_installments , 0
# payment_value , 0
# customer_id , 0
# order_status , 0
# order_purchase_timestamp , 0
# order_approved_at , 14
# order_delivered_carrier_date , 1215
# order_delivered_customer_date , 2517
# order_estimated_delivery_date , 0
# review_score , 0
# customer_unique_id , 0
# zip_code_prefix_customer , 0
# customer_city , 0
# customer_state , 0
# object_id_customer , 0
# shape_customer , 0
# admin0_name_en_customer , 0
# admin0_name_th_customer , 0
# admin0_pcode_customer , 0
# admin1_name_en_customer , 0
# admin1_name_th_customer , 0
# admin1_pcode_customer , 0
# admin2_name_en_customer , 0
# admin2_name_th_customer , 0
# admin2_pcode_customer , 0
# admin3_name_en_customer , 0
# admin3_name_th_customer , 0
# shape_length_customer , 0
# shape_area_customer , 0
# product_id , 0
# product_category_name , 0
# product_name_lenght , 0
# product_description_lenght , 0
# product_photos_qty , 0
# product_weight_g , 0
# product_length_cm , 0
# product_height_cm , 0
# product_width_cm , 0
# order_item_id , 0
# seller_id , 0
# shipping_limit_date , 0
# price , 0
# freight_value , 0
# seller_zip_code_prefix_prep , 0
# seller_city_prep , 0
# seller_state_prep , 0
# zip_code_prefix_seller , 0
# seller_city , 0
# seller_state , 0
# object_id_seller , 0
# shape_seller , 0
# admin0_name_en_seller , 0
# admin0_name_th_seller , 0
# admin0_pcode_seller , 0
# admin1_name_en_seller , 0
# admin1_name_th_seller , 0
# admin1_pcode_seller , 0
# admin2_name_en_seller , 0
# admin2_name_th_seller , 0
# admin2_pcode_seller , 0
# admin3_name_en_seller , 0
# admin3_name_th_seller , 0
# shape_length_seller , 0
# shape_area_seller , 0

# %% [markdown]
# # Remove redundant data

# %%
data["order_status"].value_counts()
# Out:
# delivered      114089
# shipped          1225
# canceled          555
# invoiced          364
# processing        362
# unavailable         7
# approved            3
# Name: order_status, dtype: int64

# %%
not_delivered = data[data["order_status"]!="delivered"]["order_status"].value_counts().sum()

print("Total number of orders which are not delivered : ",not_delivered)
print("percentage of orders which are not delivered : ", (not_delivered*100/data.shape[0]).round(3),"%")
# Out:
# Total number of orders which are not delivered :  2516
# percentage of orders which are not delivered :  2.158 %

# %%
#We are interested in products that are delivered.
#We don't need the products which are not delivered yet/ cancelled. hence let's consider only delivered orders.
# Also there are only 2.2% of data which are not delivered. 

data = data[data["order_status"]=="delivered"]

# %%
#Since we cannot impute datetime, lets drop the rows which has null values in order_approved_at,order_delivered_carrier_date,order_delivered_customer_date
#These columns has very little number of null values. 
data.dropna(subset=["order_approved_at","order_delivered_carrier_date","order_delivered_customer_date"],axis=0,inplace=True)

# %%
data.dropna(subset=["product_photos_qty","product_width_cm"],axis=0,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114066 entries, 0 to 116604
# Data columns (total 67 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       114066 non-null  object
#  1   payment_sequential             114066 non-null  int64
#  2   payment_type                   114066 non-null  object
#  3   payment_installments           114066 non-null  int64
#  4   payment_value                  114066 non-null  float64
#  5   customer_id                    114066 non-null  object
#  6   order_status                   114066 non-null  object
#  7   order_purchase_timestamp       114066 non-null  object
#  8   order_approved_at              114066 non-null  object
#  9   order_delivered_carrier_date   114066 non-null  object
#  10  order_delivered_customer_date  114066 non-null  object
#  11  order_estimated_delivery_date  114066 non-null  object
#  12  review_score                   114066 non-null  int64
#  13  customer_unique_id             114066 non-null  object
#  14  zip_code_prefix_customer       114066 non-null  object
#  15  customer_city                  114066 non-null  object
#  16  customer_state                 114066 non-null  object
#  17  object_id_customer             114066 non-null  int64
#  18  shape_customer                 114066 non-null  object
#  19  admin0_name_en_customer        114066 non-null  object
#  20  admin0_name_th_customer        114066 non-null  object
#  21  admin0_pcode_customer          114066 non-null  object
#  22  admin1_name_en_customer        114066 non-null  object
#  23  admin1_name_th_customer        114066 non-null  object
#  24  admin1_pcode_customer          114066 non-null  object
#  25  admin2_name_en_customer        114066 non-null  object
#  26  admin2_name_th_customer        114066 non-null  object
#  27  admin2_pcode_customer          114066 non-null  object
#  28  admin3_name_en_customer        114066 non-null  object
#  29  admin3_name_th_customer        114066 non-null  object
#  30  shape_length_customer          114066 non-null  float64
#  31  shape_area_customer            114066 non-null  float64
#  32  product_id                     114066 non-null  object
#  33  product_category_name          114066 non-null  object
#  34  product_name_lenght            114066 non-null  int64
#  35  product_description_lenght     114066 non-null  int64
#  36  product_photos_qty             114066 non-null  int64
#  37  product_weight_g               114066 non-null  int64
#  38  product_length_cm              114066 non-null  int64
#  39  product_height_cm              114066 non-null  int64
#  40  product_width_cm               114066 non-null  int64
#  41  order_item_id                  114066 non-null  int64
#  42  seller_id                      114066 non-null  object
#  43  shipping_limit_date            114066 non-null  object
#  44  price                          114066 non-null  float64
#  45  freight_value                  114066 non-null  float64
#  46  seller_zip_code_prefix_prep    114066 non-null  object
#  47  seller_city_prep               114066 non-null  object
#  48  seller_state_prep              114066 non-null  object
#  49  zip_code_prefix_seller         114066 non-null  object
#  50  seller_city                    114066 non-null  object
#  51  seller_state                   114066 non-null  object
#  52  object_id_seller               114066 non-null  int64
#  53  shape_seller                   114066 non-null  object
#  54  admin0_name_en_seller          114066 non-null  object
#  55  admin0_name_th_seller          114066 non-null  object
#  56  admin0_pcode_seller            114066 non-null  object
#  57  admin1_name_en_seller          114066 non-null  object
#  58  admin1_name_th_seller          114066 non-null  object
#  59  admin1_pcode_seller            114066 non-null  object
#  60  admin2_name_en_seller          114066 non-null  object
#  61  admin2_name_th_seller          114066 non-null  object
#  62  admin2_pcode_seller            114066 non-null  object
#  63  admin3_name_en_seller          114066 non-null  object
#  64  admin3_name_th_seller          114066 non-null  object
#  65  shape_length_seller            114066 non-null  float64
#  66  shape_area_seller              114066 non-null  float64
# dtypes: float64(7), int64(13), object(47)
# memory usage: 59.2+ MB

# %%
data.shape
# Out:
# (114066, 67)

# %%
# % of data that we have drooped
print("Percentage of data that we have dropped is : ",round((num_tot_rows-data.shape[0])*100/num_tot_rows,3),"%")
# Out:
# Percentage of data that we have dropped is :  2.177 %

# %% [markdown]
# So we have lost roughly 2% of data, which is not bad. Because we have 98% of data which don't have null values.

# %% [markdown]
# ## Remove duplicated data

# %%
data[data.duplicated()==True]
# Out:
#                                 order_id  payment_sequential payment_type  \
# 4       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 66      c0db7d31ace61fc360a3eaa34dd3457c                   1  credit_card
# 74      95442deb81a5d91c97c0df96b431634a                   1       boleto
# 75      95442deb81a5d91c97c0df96b431634a                   1       boleto
# 186     14d9794bbb53614d12cc2df6a045f82b                   1       boleto
# ...                                  ...                 ...          ...
# 114572  b9eb9fbcca54dfce1d087c752d0f4b35                   1       boleto
# 115660  f7c5c5ff5045e13c98901bbbf8e871d4                   1  credit_card
# 115756  169ab175fb915582d84c0c5c95bb0fe3                   1  credit_card
# 115925  03515a836bb855b03f7df9dee520a8fc                   1  credit_card
# 116180  c88b1d1b157a9999ce368f218a407141                   1  credit_card
#
#         payment_installments  payment_value                       customer_id  \
# 4                          8         107.78  7a5d8efaaa1081f800628c30d2b0728f
# 66                         5          65.71  80c0276f1c674e7b026d5a39799afaa4
# 74                         1         368.98  daddb546b42f656e57ba8a3cf71a309f
# 75                         1         368.98  daddb546b42f656e57ba8a3cf71a309f
# 186                        1         116.70  666a4eb7699fdccd19518171e0b5a069
# ...                      ...            ...                               ...
# 114572                     1          35.01  3824319059ed4febc68d625e63f29eee
# 115660                    10         231.27  1d5f7303f8a2248f42cf919af8d77cc3
# 115756                    10         741.10  fe02528abe9cf5b73ededc4a240acc9d
# 115925                    10         106.38  153e6d880db3cac30ecfeb13e0047841
# 116180                     4          42.77  ae0fb7b01c548c4fd30f19f55453ec4a
#
#        order_status order_purchase_timestamp order_approved_at  \
# 4         delivered         06/12/2017 12:04  06/12/2017 12:13
# 66        delivered         13/02/2018 16:36  13/02/2018 16:50
# 74        delivered         19/07/2018 11:54  20/07/2018 04:45
# 75        delivered         19/07/2018 11:54  20/07/2018 04:45
# 186       delivered         14/01/2018 21:10  16/01/2018 03:38
# ...             ...                      ...               ...
# 114572    delivered         11/10/2017 10:23  12/10/2017 03:00
# 115660    delivered         26/07/2017 18:22  26/07/2017 18:38
# 115756    delivered         09/06/2018 08:51  09/06/2018 09:11
# 115925    delivered         19/01/2018 13:24  19/01/2018 13:36
# 116180    delivered         17/07/2017 22:44  18/07/2017 22:50
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 4                  07/12/2017 20:28              21/12/2017 01:35
# 66                 14/02/2018 19:12              16/02/2018 18:06
# 74                 23/07/2018 08:22              26/07/2018 16:16
# 75                 23/07/2018 08:22              26/07/2018 16:16
# 186                16/01/2018 17:36              29/01/2018 18:08
# ...                             ...                           ...
# 114572             16/10/2017 22:52              25/10/2017 17:13
# 115660             28/07/2017 17:35              07/08/2017 19:22
# 115756             15/06/2018 11:32              18/06/2018 19:58
# 115925             19/01/2018 21:47              05/02/2018 14:33
# 116180             20/07/2017 15:27              21/07/2017 17:06
#
#        order_estimated_delivery_date  review_score  \
# 4                   04/01/2018 00:00             5
# 66                  23/02/2018 00:00             5
# 74                  02/08/2018 00:00             5
# 75                  02/08/2018 00:00             5
# 186                 16/02/2018 00:00             5
# ...                              ...           ...
# 114572              09/11/2017 00:00             5
# 115660              18/08/2017 00:00             5
# 115756              04/07/2018 00:00             5
# 115925              01/03/2018 00:00             5
# 116180              01/08/2017 00:00             5
#
#                       customer_unique_id zip_code_prefix_customer  \
# 4       87695ed086ebd36f20404c82d20fca87                 TH940710
# 66      271d3cdd872021b1b6669ad93e8b856b                 TH302405
# 74      5b7f468205743c98e58a379722d3ae79                 TH810115
# 75      5b7f468205743c98e58a379722d3ae79                 TH810115
# 186     e301216623168d227eb0b0a3aabb1e62                 TH250803
# ...                                  ...                      ...
# 114572  b088bc1ec6539752bf408ac1d9c694da                 TH240309
# 115660  f7ac7452ae241a5a36aaf9542c2428d5                 TH340713
# 115756  e0f902e5e7b9818dc9b7f34eaffb6932                 TH460121
# 115925  159306b86e782097be9a4e29e3d294d3                 TH471007
# 116180  b64ebaf3d11b7209fe566364cc359a51                 TH460117
#
#          customer_city     customer_state  object_id_customer shape_customer  \
# 4             Sai Buri            Pattani                4799        Polygon
# 66           Non Daeng  Nakhon Ratchasima                1454        Polygon
# 74        Mueang Krabi              Krabi                5663        Polygon
# 75        Mueang Krabi              Krabi                5663        Polygon
# 186       Si Maha Phot       Prachin Buri                 453        Polygon
# ...                ...                ...                 ...            ...
# 114572  Bang Nam Priao       Chachoengsao                5698        Polygon
# 115660        Det Udom   Ubon Ratchathani                6564        Polygon
# 115756  Mueang Kalasin            Kalasin                2948        Polygon
# 115925       Ban Muang       Sakon Nakhon                4048        Polygon
# 116180  Mueang Kalasin            Kalasin                2053        Polygon
#
#        admin0_name_en_customer admin0_name_th_customer admin0_pcode_customer  \
# 4                     Thailand               ประเทศไทย                    TH
# 66                    Thailand               ประเทศไทย                    TH
# 74                    Thailand               ประเทศไทย                    TH
# 75                    Thailand               ประเทศไทย                    TH
# 186                   Thailand               ประเทศไทย                    TH
# ...                        ...                     ...                   ...
# 114572                Thailand               ประเทศไทย                    TH
# 115660                Thailand               ประเทศไทย                    TH
# 115756                Thailand               ประเทศไทย                    TH
# 115925                Thailand               ประเทศไทย                    TH
# 116180                Thailand               ประเทศไทย                    TH
#
#        admin1_name_en_customer admin1_name_th_customer admin1_pcode_customer  \
# 4                      Pattani                 ปัตตานี                  TH94
# 66           Nakhon Ratchasima              นครราชสีมา                  TH30
# 74                       Krabi                  กระบี่                  TH81
# 75                       Krabi                  กระบี่                  TH81
# 186               Prachin Buri              ปราจีนบุรี                  TH25
# ...                        ...                     ...                   ...
# 114572            Chachoengsao              ฉะเชิงเทรา                  TH24
# 115660        Ubon Ratchathani             อุบลราชธานี                  TH34
# 115756                 Kalasin               กาฬสินธุ์                  TH46
# 115925            Sakon Nakhon                  สกลนคร                  TH47
# 116180                 Kalasin               กาฬสินธุ์                  TH46
#
#        admin2_name_en_customer admin2_name_th_customer admin2_pcode_customer  \
# 4                     Sai Buri                 สายบุรี                TH9407
# 66                   Non Daeng                  โนนแดง                TH3024
# 74                Mueang Krabi             เมืองกระบี่                TH8101
# 75                Mueang Krabi             เมืองกระบี่                TH8101
# 186               Si Maha Phot              ศรีมหาโพธิ                TH2508
# ...                        ...                     ...                   ...
# 114572          Bang Nam Priao           บางน้ำเปรี้ยว                TH2403
# 115660                Det Udom                 เดชอุดม                TH3407
# 115756          Mueang Kalasin          เมืองกาฬสินธุ์                TH4601
# 115925               Ban Muang                บ้านม่วง                TH4710
# 116180          Mueang Kalasin          เมืองกาฬสินธุ์                TH4601
#
#        admin3_name_en_customer admin3_name_th_customer  shape_length_customer  \
# 4                         Paen                    แป้น               0.167193
# 66                 Don Yao Yai              ดอนยาวใหญ่               0.251575
# 74                    Sai Thai                   ไสไทย               0.424423
# 75                    Sai Thai                   ไสไทย               0.424423
# 186                   Ban Tham                 บ้านทาม               0.405921
# ...                        ...                     ...                    ...
# 114572              Sala Daeng                 ศาลาแดง               0.352865
# 115660              Tha Pho Si             ท่าโพธิ์ศรี               0.476245
# 115756              Lam Khlong                  ลำคลอง               0.293542
# 115925               Non Sa-At                โนนสะอาด               0.405447
# 116180                  Khamin                   ขมิ้น               0.371793
#
#         shape_area_customer                        product_id  \
# 4                  0.001690  548e5bfe28edceab6b51fa707cc9556f
# 66                 0.002014  22c5ddc22ea8cae84fc9917def682dc6
# 74                 0.004532  98eb4ae2cc4f0aa3f5c7762583b71e51
# 75                 0.004532  98eb4ae2cc4f0aa3f5c7762583b71e51
# 186                0.001999  e53e557d5a159f5aa2c5e995dfdf244b
# ...                     ...                               ...
# 114572             0.002839  70afaf5a0fe1e5947d15e7f3751f390f
# 115660             0.006661  952670bc019a73f0933157ec82ff6e4f
# 115756             0.002023  92ff4701412588ba89562a5da013c537
# 115925             0.005022  2b4609f8948be18874494203496bc318
# 116180             0.004483  b1acb7e8152c90c9619897753a75c973
#
#          product_category_name  product_name_lenght  \
# 4              cama_mesa_banho                   60
# 66                  perfumaria                   24
# 74             cama_mesa_banho                   56
# 75             cama_mesa_banho                   56
# 186     informatica_acessorios                   33
# ...                        ...                  ...
# 114572               papelaria                   37
# 115660         cama_mesa_banho                   46
# 115756        eletrodomesticos                   33
# 115925            beleza_saude                   59
# 116180            beleza_saude                   56
#
#         product_description_lenght  product_photos_qty  product_weight_g  \
# 4                              188                   1              1200
# 66                             435                   3               350
# 74                            1361                   1              1350
# 75                            1361                   1              1350
# 186                            256                   1               180
# ...                            ...                 ...               ...
# 114572                         151                   1               200
# 115660                         162                   5              3300
# 115756                          96                   1             21000
# 115925                         492                   3               250
# 116180                         575                   1               200
#
#         product_length_cm  product_height_cm  product_width_cm  order_item_id  \
# 4                      44                  2                35              1
# 66                     25                 15                15              1
# 74                     32                  4                22              1
# 75                     32                  4                22              2
# 186                    17                 10                13              1
# ...                   ...                ...               ...            ...
# 114572                 16                 10                11              1
# 115660                 60                 18                50              1
# 115756                 63                 21                37              1
# 115925                 22                 10                18              1
# 116180                 20                 15                15              1
#
#                                seller_id shipping_limit_date   price  \
# 4       da8622b14eb17ae2831f4ac5b9dab84a    12/12/2017 12:13   89.90
# 66      cc419e0650a3c5ba77189a1882b7556a    22/02/2018 15:50   56.99
# 74      7d456afc660226829370f3173d14520c    24/07/2018 04:45  169.00
# 75      7d456afc660226829370f3173d14520c    24/07/2018 04:45  169.00
# 186     0b90b6df587eb83608a64ea8b390cf07    26/01/2018 03:38   99.56
# ...                                  ...                 ...     ...
# 114572  e06f09ec0a4aca210779cf1cfc63cf19    24/10/2017 04:00   18.90
# 115660  37be5a7c751166fbc5f8ccba4119e043    02/08/2017 18:36  205.00
# 115756  e882b2a25a10b9c057cc49695f222c19    14/06/2018 09:11  662.73
# 115925  cc419e0650a3c5ba77189a1882b7556a    29/01/2018 13:36   89.99
# 116180  cc419e0650a3c5ba77189a1882b7556a    26/07/2017 22:50   34.99
#
#         freight_value seller_zip_code_prefix_prep seller_city_prep  \
# 4               17.88                    TH190403      Wihan Daeng
# 66               8.72                    TH320113     Mueang Surin
# 74              15.49                    TH520101   Mueang Lampang
# 75              15.49                    TH520101   Mueang Lampang
# 186             17.14                    TH330804         Khun Han
# ...               ...                         ...              ...
# 114572          16.11                    TH120505          Sai Noi
# 115660          26.27                    TH240305   Bang Nam Priao
# 115756          78.37                    TH160605           Ban Mi
# 115925          16.39                    TH320113     Mueang Surin
# 116180           7.78                    TH320113     Mueang Surin
#
#        seller_state_prep zip_code_prefix_seller     seller_city  seller_state  \
# 4               Saraburi               TH190403     Wihan Daeng      Saraburi
# 66                 Surin               TH320113    Mueang Surin         Surin
# 74               Lampang               TH520101  Mueang Lampang       Lampang
# 75               Lampang               TH520101  Mueang Lampang       Lampang
# 186            Si Sa Ket               TH330804        Khun Han     Si Sa Ket
# ...                  ...                    ...             ...           ...
# 114572        Nonthaburi               TH120505         Sai Noi    Nonthaburi
# 115660      Chachoengsao               TH240305  Bang Nam Priao  Chachoengsao
# 115756          Lop Buri               TH160605          Ban Mi      Lop Buri
# 115925             Surin               TH320113    Mueang Surin         Surin
# 116180             Surin               TH320113    Mueang Surin         Surin
#
#         object_id_seller shape_seller admin0_name_en_seller  \
# 4                   2291      Polygon              Thailand
# 66                  5962      Polygon              Thailand
# 74                  7316      Polygon              Thailand
# 75                  7316      Polygon              Thailand
# 186                 5132      Polygon              Thailand
# ...                  ...          ...                   ...
# 114572              2611      Polygon              Thailand
# 115660               952      Polygon              Thailand
# 115756                84      Polygon              Thailand
# 115925              5962      Polygon              Thailand
# 116180              5962      Polygon              Thailand
#
#        admin0_name_th_seller admin0_pcode_seller admin1_name_en_seller  \
# 4                  ประเทศไทย                  TH              Saraburi
# 66                 ประเทศไทย                  TH                 Surin
# 74                 ประเทศไทย                  TH               Lampang
# 75                 ประเทศไทย                  TH               Lampang
# 186                ประเทศไทย                  TH             Si Sa Ket
# ...                      ...                 ...                   ...
# 114572             ประเทศไทย                  TH            Nonthaburi
# 115660             ประเทศไทย                  TH          Chachoengsao
# 115756             ประเทศไทย                  TH              Lop Buri
# 115925             ประเทศไทย                  TH                 Surin
# 116180             ประเทศไทย                  TH                 Surin
#
#        admin1_name_th_seller admin1_pcode_seller admin2_name_en_seller  \
# 4                    สระบุรี                TH19           Wihan Daeng
# 66                  สุรินทร์                TH32          Mueang Surin
# 74                     ลำปาง                TH52        Mueang Lampang
# 75                     ลำปาง                TH52        Mueang Lampang
# 186                 ศรีสะเกษ                TH33              Khun Han
# ...                      ...                 ...                   ...
# 114572               นนทบุรี                TH12               Sai Noi
# 115660            ฉะเชิงเทรา                TH24        Bang Nam Priao
# 115756                ลพบุรี                TH16                Ban Mi
# 115925              สุรินทร์                TH32          Mueang Surin
# 116180              สุรินทร์                TH32          Mueang Surin
#
#        admin2_name_th_seller admin2_pcode_seller admin3_name_en_seller  \
# 4                   วิหารแดง              TH1904           Khlong Ruea
# 66             เมืองสุรินทร์              TH3201                 Sawai
# 74                เมืองลำปาง              TH5201            Wiang Nuea
# 75                เมืองลำปาง              TH5201            Wiang Nuea
# 186                   ขุนหาญ              TH3308              Pho Wong
# ...                      ...                 ...                   ...
# 114572               ไทรน้อย              TH1205               Khun Si
# 115660         บางน้ำเปรี้ยว              TH2403         Bueng Nam Rak
# 115756              บ้านหมี่              TH1606               Ban Chi
# 115925         เมืองสุรินทร์              TH3201                 Sawai
# 116180         เมืองสุรินทร์              TH3201                 Sawai
#
#        admin3_name_th_seller  shape_length_seller  shape_area_seller
# 4                   คลองเรือ             0.293141           0.003177
# 66                      สวาย             0.450106           0.006100
# 74                เวียงเหนือ             0.100080           0.000282
# 75                เวียงเหนือ             0.100080           0.000282
# 186                โพธิ์วงศ์             0.208137           0.001799
# ...                      ...                  ...                ...
# 114572                ขุนศรี             0.241330           0.002058
# 115660           บึงน้ำรักษ์             0.294272           0.003659
# 115756                บ้านชี             0.232046           0.002722
# 115925                  สวาย             0.450106           0.006100
# 116180                  สวาย             0.450106           0.006100
#
# [406 rows x 67 columns]

# %%
#remove the duplicates
data.drop_duplicates(keep="first",inplace=True)

# %%
data.shape
# Out:
# (113660, 67)

# %%
#lets change the datetime features to correct format
data["order_purchase_timestamp"]       = pd.to_datetime(data["order_purchase_timestamp"])
data["order_approved_at"]              = pd.to_datetime(data["order_approved_at"])
data["order_delivered_carrier_date"]   = pd.to_datetime(data["order_delivered_carrier_date"])
data["order_delivered_customer_date"]  = pd.to_datetime(data["order_delivered_customer_date"])
data["order_estimated_delivery_date"]  = pd.to_datetime(data["order_estimated_delivery_date"])
data["shipping_limit_date"]            = pd.to_datetime(data["shipping_limit_date"])

# %% [markdown]
# ## map the product_category translation to data

# %%
translation.rename(columns = {"product_category_name_portugese":"product_category_name"},inplace=True)
data = pd.merge(data,translation,how="left",on="product_category_name")

# %%
data[data["product_category_name_english"].isnull()==True]["product_category_name"].value_counts()
# Out:
# portateis_cozinha_e_preparadores_de_alimentos    14
# pc_gamer                                          9
# Name: product_category_name, dtype: int64

# %%
translation[translation["product_category_name"]=="portateis_cozinha_e_preparadores_de_alimentos"]
# Out:
# Empty DataFrame
# Columns: [product_category_name, product_category_name_english]
# Index: []

# %% [markdown]
# Translation data does not have "portateis_cozinha_e_preparadores_de_alimentos", "pc_gamer".
#
# "portateis_cozinha_e_preparadores_de_alimentos" english translation is "kitchen_laptops_and_food_preparators"
#
# "pc_gamer" is "pc_gamer".
# Let us fill the null values in english translation by these values.

# %%
null_1 = data[data["product_category_name"]=="portateis_cozinha_e_preparadores_de_alimentos"]["product_category_name_english"]
null_2 = data[data["product_category_name"]=="pc_gamer"]["product_category_name_english"]

# %%
data.loc[null_1.index,"product_category_name_english"] = "kitchen_laptops_and_food_preparators"
data.loc[null_2.index,"product_category_name_english"] = "pc_gamer"

# %%
data.drop("product_category_name",inplace=True,axis=1)
data.rename(columns={"product_category_name_english":"product_category_name"},inplace=True)

# %% [markdown]
# ## Save final data frame

# %%
#let us save the data as final_data.csv, so that we do not need to run the above cells again.
data.to_csv("C:/Users/ccher/OneDrive/Desktop/PwC Assn/final_data.csv")

# %% [markdown]
# # EDA

# %%
#load the data
data = pd.read_csv("final_data.csv")
data.drop("Unnamed: 0",axis=1,inplace=True)

# %%
rate_1 = data[data["review_score"]==1] 
rate_2 = data[data["review_score"]==2] 
rate_3 = data[data["review_score"]==3] 
rate_4 = data[data["review_score"]==4] 
rate_5 = data[data["review_score"]==5]

# %% [markdown]
# Let us check the distribution of class label to understand the class balance

# %%
rate_5["product_category_name"].value_counts()[:10].plot.bar(figsize=(10,5)).legend()
plt.xlabel("product category name")
plt.ylabel("Counts")
plt.title("Top 10 product categroy in review score 5")
plt.show()

print("Percentage cover of top 10 categories in review score 5 : ")
print((rate_5["product_category_name"].value_counts(normalize=True)[:10].sum()*100).round(3),"%")
# Out:
# Percentage cover of top 10 categories in review score 5 :
# 63.911 %

# %% [markdown]
# - bed_bath_table is the most occuring category in rating 5, followed by health_beauty
# - We can see the top 10 categories in review score 5 cover 63.9% of categories.

# %%
data["product_category_name"].value_counts()[:10].plot.bar(figsize=(10,5)).legend()
plt.xlabel("product category name")
plt.ylabel("Counts")
plt.title("Top 10 product category")
plt.show()

print("Percentage cover of top 10 categories : ")
print((data["product_category_name"].value_counts(normalize=True)[:10].sum()*100).round(3),"%")
# Out:
# Percentage cover of top 10 categories :
# 64.568 %
